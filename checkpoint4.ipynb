# %% [markdown]
# # data preprocessing

# %%
import pandas as pd
import numpy as np
sheet = pd.read_csv(r"C:\Users\hp\Desktop\python\kc_house_data.csv")
df=pd.DataFrame(sheet)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
df['yr_built'].value_counts()
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df['sqft_above'].value_counts()
# Out:
# 1300    212
# 1010    210
# 1200    206
# 1220    192
# 1140    184
#        ...
# 2665      1
# 2601      1
# 440       1
# 2473      1
# 1975      1
# Name: sqft_above, Length: 946, dtype: int64

# %%
df['sqft_lot'].value_counts()
# Out:
# 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     120
#         ...
# 38884      1
# 17313      1
# 35752      1
# 937        1
# 14321      1
# Name: sqft_lot, Length: 9782, dtype: int64

# %%
df['sqft_lot15'].value_counts()
# Out:
# 5000      427
# 4000      357
# 6000      289
# 7200      211
# 4800      145
#          ...
# 8989        1
# 871200      1
# 809         1
# 4907        1
# 6147        1
# Name: sqft_lot15, Length: 8689, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df=df.drop("waterfront",axis=1)

# %%
df=df.drop("id",axis=1)

# %%
df=df.drop("yr_renovated",axis=1)

# %%
df=df.drop("date",axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  221900.0         3       1.00         1180      5650     1.0     0
# 1  538000.0         3       2.25         2570      7242     2.0     0
# 2  180000.0         2       1.00          770     10000     1.0     0
# 3  604000.0         4       3.00         1960      5000     1.0     0
# 4  510000.0         3       2.00         1680      8080     1.0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  zipcode      lat  \
# 0          3      7        1180              0      1955    98178  47.5112
# 1          3      7        2170            400      1951    98125  47.7210
# 2          3      6         770              0      1933    98028  47.7379
# 3          5      7        1050            910      1965    98136  47.5208
# 4          3      8        1680              0      1987    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# ...

# %%
df['grade'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['price'])
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(data=df, x="bedrooms", y="price")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(data=df, x="zipcode", y="price")
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='price'>

# %%
sns.scatterplot(data=df, x="long", y="price")
# Out:
# <AxesSubplot:xlabel='long', ylabel='price'>

# %%
sns.scatterplot(data=df, x="lat", y="price")
# Out:
# <AxesSubplot:xlabel='lat', ylabel='price'>

# %%
sns.scatterplot(data=df, x="condition",y="price")
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
sns.scatterplot(data=df, x="view", y="price")
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
sns.scatterplot(data=df, x="grade", y="price")
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
sns.scatterplot(data=df, x="yr_built", y="price")
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_above", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_living", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_living15", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_lot", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_lot15", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_lot15', ylabel='price'>

# %%
sns.scatterplot(data=df, x="sqft_basement", y="price")
# Out:
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %%
g=sns.FacetGrid(df,col='view')
g.map(plt.hist, 'price',bins=80)

# %%
g=sns.FacetGrid(df,col='floors')
g.map(plt.hist, 'price',bins=80)

# %%
g=sns.FacetGrid(df,col='condition')
g.map(plt.hist, 'price',bins=80)

# %%
df[['condition','price']].groupby(['condition'],as_index=True).mean()
# Out:
#                    price
# condition
# 1          334431.666667
# 2          327287.145349
# 3          542012.578148
# 4          521200.390033
# 5          612418.089359

# %%
df[['view','price']].groupby(['view'],as_index=True).mean()
# Out:
#              price
# view
# 0     4.965642e+05
# 1     8.122808e+05
# 2     7.924009e+05
# 3     9.719653e+05
# 4     1.463711e+06

# %%
df[['grade','price']].groupby(['grade'],as_index=True).mean()
# Out:
#               price
# grade
# 1      1.420000e+05
# 3      2.056667e+05
# 4      2.143810e+05
# 5      2.485240e+05
# 6      3.019196e+05
# 7      4.025903e+05
# 8      5.428528e+05
# 9      7.735132e+05
# 10     1.071771e+06
# 11     1.496842e+06
# 12     2.191222e+06
# 13     3.709615e+06

# %%
df[['floors','price']].groupby(['floors'],as_index=True).mean()
# Out:
#                price
# floors
# 1.0     4.421806e+05
# 1.5     5.589806e+05
# 2.0     6.488912e+05
# 2.5     1.060346e+06
# 3.0     5.825260e+05
# 3.5     9.333125e+05

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='view',data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='condition',data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='grade',data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='floors',data=df)
plt.show()

# %%
def plot_correlation_map( data ):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12}

        )

    
plot_correlation_map(df)

# %% [markdown]
# # machine learning
# ## question 3

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

# %%
len(x_test)
# Out:
# 7565

# %%
len(x_train)
# Out:
# 14048

# %%
x_train
# Out:
# array([[1060],
#        [2940],
#        [1180],
#        ...,
#        [1150],
#        [2460],
#        [1250]], dtype=int64)

# %% [markdown]
# ## question 4

# %%
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

# %% [markdown]
# ## question 5 a

# %%
#Linear Regression plot
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %% [markdown]
# ## question 5 b

# %%
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %% [markdown]
# ## question 6

# %%
x=df[["sqft_living","sqft_above"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62831668851.97097
# R squared 0.5002155345241335

# %%
x=df[["sqft_living","sqft_above","bathrooms","sqft_living15"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 61915032932.83282
# R squared 0.5075067684075076

# %%
x=df[["sqft_living","sqft_above","bathrooms","sqft_living15","grade"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 56262505729.608925
# R squared 0.5524688924202686

# %% [raw]
# Régression linéaire multiple:
# R^2(sqft_living,sqft_above,bathrooms,sqft_living15,grade)=0.55>R^2(sqft_living,sqft_above,bathrooms,sqft_living15)>R^2(sqft_living,sqft_above,bathrooms,sqft_living15)=0.5075>R^2(sqft_living,sqft_above)=0.5002
# ==>donc pour la regression linéaire multiple les variables d'entrée qui fournit de bons  resultat sont    (sqft_living,sqft_above,bathrooms,sqft_living15,grade)

# %% [raw]
# R^2(regression linéaire)=0.49<R^2(Régression linéaire multiple)=0.55
# ==>donc la regression linéaire multiple est plus précis que la regression linéaire

# %% [markdown]
# # # question 7

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=df[["sqft_living","sqft_above","bathrooms","sqft_living15","grade"]]  #we have more than one input
y=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  48445338738.99114
# R squared:  0.6146492975778334

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=df[["sqft_living","sqft_above","bathrooms","sqft_living15"]]  #we have more than one input
y=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57178732194.06497
# R squared:  0.5451809154787068

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=df[["sqft_living","sqft_above"]]  #we have more than one input
y=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=2)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57614849407.98967
# R squared:  0.5417118908191885

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x=df[["sqft_living","sqft_above"]]  #we have more than one input
y=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57232313792.28893
# R squared:  0.5447547092213052

# %% [raw]
# régression polynomiale:(degré=3)
# R^2(sqft_living,sqft_above)=0.5447<=R^2(sqft_living,sqft_above,bathrooms,sqft_living15)=0.5451<R^2(sqft_living,sqft_above, bathrooms,sqft_living15,grade)=0.61
# les variables d'entrée sont (sqft_living,sqft_above,bathrooms,sqft_living15,grade)
# R^2(regression linéaire)=0.49<R^2(Régression linéaire multiple)=0.55R^2<(régression polynomiale:(degré=3))=0.61
# ===> donc la régression polynomiale le modéle le plus adaptable .
